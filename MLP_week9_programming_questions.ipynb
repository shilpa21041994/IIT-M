# %% [markdown]
# <a href="https://colab.research.google.com/github/shilpa21041994/IIT-M/blob/main/MLP_week9_programming_questions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# There are 6 practice questions and 10 graded questions in this document.
#
#
# ---

# %% [markdown]
# #Instructions for Practice Questions 1-3
#
# - Load sklearn's wine dataset.
# - Split the dataset into train and test set with 70:30 ratio with `random_state = 1`.
# - Train using DecisionTreeClassifier with `random_state = 1` and other values being default
#
# #Practice Question 1: Enter the value of the 'score' on training set.
#
# (NAT) **Answer: 1.0 (Range : 0.99-1.01)**
#
# #Practice Question 2: Enter the value of the 'score' on testing set.
#
# (NAT) **Answer: 0.9444 (Range : 0.9434-0.9454)**
#
# #Practice Question 3: What is the level of depth of the trained decision tree.
# (NAT)  **Answer: 6**

# %% [markdown]
# **Solution**

# %%
import numpy as np
import sklearn
import pandas as pd

from sklearn.datasets import load_wine
df = load_wine()

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df.data, df.target, test_size=0.3, random_state = 1)

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(random_state = 1)
model.fit(X_train, y_train)
print('Score on Training set is:',model.score(X_train,y_train))
print('Score on Testing set is:', model.score(X_test,y_test))
print('Tree Depth Level is :', model.get_depth())
# Out:
# Score on Training set is: 1.0
# Score on Testing set is: 0.9444444444444444
# Tree Depth Level is : 6

# %% [markdown]
# #Instructions for Practice Questions 4-6
#
# - Load sklearn's wine dataset.
# - Split the dataset into train and test set with 70:30 ratio with `random_state = 1`.
# - Train using DecisionTreeClassifier with `random_state = 1` and the following parameters:
#
#   -- Use criterion as 'entropy'
#
#   -- Use splitter as 'random'; default is 'best'
#
#   -- maximum depth = 3
#
#   -- minimum samples required to split = 4
#
#   -- Use minimum impurity decrease as 0.1
#
#   -- Train the 'model' and compute the 'score' on training data and test data
#
# #Practice Question 4: Enter the value of the 'score' on training set.
#
# (NAT) **Answer: 0.8145 (Range : 0.8135-0.8155)**
#
# #Practice Question 5: Enter the value of the 'score' on testing set.
#
# (NAT) **Answer: 0.7778 (Range : 0.7768-0.7788)**
#
# #Practice Question 6: What is the value of entropy at the root node. (Hint: For this, you may visualize the tree)
#
# (NAT)  **Answer: 1.562 (Range : 1.5610-1.5630)**

# %%
import numpy as np
import sklearn
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn import tree


from sklearn.datasets import load_wine
df = load_wine()

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df.data, df.target, test_size=0.3, random_state = 1)

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(criterion = 'entropy', splitter = 'random', max_depth = 3, min_samples_split = 4, min_impurity_decrease = 0.1, random_state = 1)
model.fit(X_train, y_train)
print('Score on Training set is:',model.score(X_train,y_train))
print('Score on Testing set is:', model.score(X_test,y_test))

#plt the figure, setting a black background
plt.figure(figsize=(20,8), facecolor ='w')

feature_names = df.feature_names
#create the tree plot
a = tree.plot_tree(model,
                   #use the feature names stored
                   feature_names = feature_names,
                   #use the class names stored
                   
                   rounded = True,
                   filled = True,
                   fontsize=12)
#show the plot
plt.show()
# Out:
# Score on Training set is: 0.8145161290322581
# Score on Testing set is: 0.7777777777777778

# %% [markdown]
# #Instructions for Graded Questions 1-3
#
# - Load sklearn's Wine dataset.
# - Split the dataset into train and test set with 70:30 ratio with `random_state = 1`.
# - Use DecisionTreeClassifier with `random_state = 1`
# - Hyperparameter tuning to be done over the following parameters:
#
#   -- Use criterion as 'entropy' or 'gini'
#
#   -- Use splitter as 'random' or 'best'
#
#   -- Use minimum number of samples per leaf as [2,4,6,8,10]
#
#   -- Use maximum depth as [3,4,5,6]
#
#   -- Use cross validation = 4
#
#   -- Train the 'model'
#
# #Graded Question 1: Enter the value of the 'score' on testing set.
#
# (NAT) **Answer: 0.9074 (Range : 0.9064-0.9084)**
#
# #Graded Question 2: Enter the value of best max_depth of the model after training with GridSearchCV.
#
# (NAT) **Answer: 4**
#
# #Graded Question 3: Enter the value of best min_samples_leaf of the model after training with GridSearchCV
#
# (NAT)  **Answer: 2**

# %%
import numpy as np
import sklearn
import pandas as pd

from sklearn.datasets import load_wine
df = load_wine()

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df.data, df.target, test_size=0.3, random_state = 1)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier


decisiontreeclassifier = DecisionTreeClassifier(random_state = 1)

decisiontreeclassifier_model = GridSearchCV(decisiontreeclassifier,
                        {'criterion':['entropy', 'gini'],
                          'splitter':['random','best'],
                          'min_samples_leaf':[2,4,6,8,10],
                          'max_depth':[3,4,5,6]
                          } ,
                        cv = 4, 
                        return_train_score = True)
decisiontreeclassifier_model.fit(X_train, y_train)
score = decisiontreeclassifier_model.score(X_test,y_test)
print(score)
print(decisiontreeclassifier_model.best_params_)
# Out:
# 0.9074074074074074
# {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 2, 'splitter': 'best'}

# %% [markdown]
# #Instructions for Graded Questions 4-7
#
# - Load sklearn's Diabetes dataset.
# - Split the dataset into train and test set with 70:30 ratio with `random_state = 1`.
# - Use DecisionTreeRegressor with `random_state = 1` and the following parameters:
#
#   -- Use criterion as 'squared_error'
#
#   -- Use splitter as 'random'
#
#   -- Use max_leaf_nodes= 10,
#
#   -- Train the 'model' and compute the 'score' on training data and test data
#
# #Graded Question 4: Enter the value of the 'score' on training set.
#
# (NAT) **Answer: 0.5032 (Range : 0.5022-0.5042)**
#
# #Graded Question 5: Enter the value of the 'score' on testing set.
#
# (NAT) **Answer: 0.2188 (Range : 0.2178-0.2198)**
#
# #Graded Question 6: What is the value of squared_error at the root node. (Hint: Visualize the tree.)
# (NAT)  **Answer: 6302.895 (Range: 6300-6304)**
#
# #Graded Question 7: What is the ratio of number of samples in the left child node to the number of samples in the right child node of root (i.e., one level down the root node)?
#
# (NAT)  **Answer: 0.1839 (Range: 0.18-0.2)**

# %%
import numpy as np
import sklearn
import pandas as pd

from sklearn.datasets import load_diabetes
df = load_diabetes()

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df.data, df.target, test_size=0.3, random_state = 1)

# %%
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor(criterion = 'squared_error', splitter = 'random', max_leaf_nodes= 10, random_state = 1)
model.fit(X_train, y_train)
print('Score on Training set is:',model.score(X_train,y_train))
print('Score on Testing set is:', model.score(X_test,y_test))

#plt the figure, setting a black background
plt.figure(figsize=(20,8), facecolor ='w')

feature_names = df.feature_names
#create the tree plot
a = tree.plot_tree(model,
                   #use the feature names stored
                   feature_names = feature_names,
                   #use the class names stored
                   
                   rounded = True,
                   filled = True,
                   fontsize=12)
#show the plot
plt.show()
# Out:
# Score on Training set is: 0.5032060624566737
# Score on Testing set is: 0.218771375137222

# %% [markdown]
# #Instructions for Graded Questions 8-10
#
# - Load the diabetes dataset from sklearn.
# - Split the dataset into train and test set with 70:30 ratio with `random_state = 1`.
# - Use DecisionTreeRegressor with `max_depth = 4` and `random_state = 1` and other values being default.
# - Perform Hyperparameter tuning over the following parameters:
#
#   -- Use criterion as ['squared_error', 'friedman_mse', 'absolute_error', 'poisson']
#
#   -- Use splitter as 'random' or 'best'
#
#   -- Use max number of features as ['auto','sqrt', 'log2'],
#
#   -- Use cost complexity pruning parameter as [0.001,0.01,0.02,0.05]
#
#   -- Use cross validation = 4
#
# #Graded Question 8: Enter the value of the 'score' on testing set.
#
# (NAT) **Answer: 0.1087 (Range : 0.1077 - 0.1097)**
#
# #Graded Question 9: Enter the value of the best ccp_alpha of the model after performing GridSearchCV.
#
# (NAT) **Answer: 0.02 (Range: 0.015 to 0.025)**
#
# #Graded Question 10: What is the value of the best max_features criteria after performing GridSearchCV?
#
# (a) 'auto'
#
# (b) 'sqrt'
#
# (c) 'log2'
#
# (MCQ)  **Answer: (a) auto**

# %%
import numpy as np
import sklearn
import pandas as pd

from sklearn.datasets import load_diabetes
df = load_diabetes()

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df.data, df.target, test_size=0.3, random_state = 1)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor


estimator = DecisionTreeRegressor(max_depth = 4, random_state = 1)

estimator_model = GridSearchCV(estimator,
       {'criterion':['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],
        'splitter':['random','best'],
        'max_features': ['auto','sqrt', 'log2'],
        'ccp_alpha': [0.001,0.01,0.02,0.05]},
        cv = 4, return_train_score = True)
estimator_model.fit(X_train, y_train)
score = estimator_model.score(X_test,y_test)
print(score)
estimator_model.best_params_
# Out:
# 0.10873445074064803
# {'ccp_alpha': 0.02,
#  'criterion': 'absolute_error',
#  'max_features': 'auto',
#  'splitter': 'best'}
